# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
# ingest raw data
obs_df = pd.read_csv('observations.csv', skipinitialspace=True)
spec_df = pd.read_csv('species_info.csv', skipinitialspace=True)

# clean up data frames

''' We see multiple recorded observations for one location and species type (ex: Echinochloa crus-galli @ 
Bryce has obs of 112 and 116). To err on the side of caution, this report is going to be considering the 
lowest of all of the values for specific species/ location combinations (e.g: 112 from the above example.)'''

# sort by the number of observations (smaller first), then keep smallest of duplicates
obs_df_cleaned = obs_df.sort_values('observations', ascending=True).drop_duplicates(['scientific_name', 'park_name'], keep= 'first').sort_index() # from https://stackoverflow.com/questions/12497402/remove-duplicates-by-columns-a-keeping-the-row-with-the-highest-value-in-column/68876659#68876659


''' We also see multiple duplicates in the species information. Upon review, we have multiple common names 
and conservation statuses for a single species (ex: Canis lupus is both endangered and in recovery). In a 
similar approch, this analysis will bias towards caution -- marking a species as Endangered rather than 
In Recovery when there is a conflict. All common names have been combined to keep their values intact.'''

# combine all common names for each scientific name
spec_names = spec_df.groupby(['scientific_name'])['common_names'].apply(', '.join).reset_index() # from https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby

# assign all common names back to species data frame
spec_df_named = pd.merge(spec_df, spec_names, on= 'scientific_name', how= 'left')

# drop old common names column
spec_df_named = spec_df_named.drop(columns= 'common_names_x')

# rename new common names column
spec_df_named.rename(columns= {'common_names_y': 'common_names'}, errors="raise", inplace= True)

# remove redundant names from common names column
spec_df_named['common_names'] = spec_df_named['common_names'].str.replace(' ,', ',')
spec_df_named['common_names'] = spec_df_named['common_names'].str.replace(', ', ',')
spec_df_named['common_names']=spec_df_named['common_names'].str.split(',').apply(lambda x : ', '.join(set(x)))

# encode data to enable sorting by conservation status for duplicates (Endangered > Threatened > Species of Concern > In Recovery > None)
spec_df_named['conservation_status'] = spec_df_named['conservation_status'].replace(np.nan, 'None')
spec_df_named['conservation_group'] = pd.Categorical(spec_df_named['conservation_status'], ordered=True, categories=['None', 'In Recovery', 'Species of Concern', 'Threatened', 'Endangered'])

# drop duplicate species keeping the most conservative level in conservation group
spec_df_named = spec_df_named.sort_values('conservation_group', ascending=True).drop_duplicates(['scientific_name'], keep= 'last')

# drop column used for sorting
spec_df_named = spec_df_named.drop('conservation_group', 1)
spec_df_named.to_csv('spec_df.csv')

# combine all data into single data frame
bio_df = pd.merge(spec_df_named, obs_df_cleaned, on= 'scientific_name', how= 'left')

# confirm merge using original csvs # confirmed
# bio_df[bio_df['conservation_status'] == 'Endangered'].head(10)

bio_df.head()
# bio_df.to_csv('bio_df.csv')
bio_df.describe(include='all')

bio_df_troubled = bio_df.loc[bio_df['conservation_status'] != 'None']

bio_df_troubled_renamed_parks = bio_df_troubled.replace({'Bryce National Park': 'Bryce', 
                                                         'Great Smoky Mountains National Park': 'Great Smoky Mountains', 
                                                         'Yosemite National Park': 'Yosemite', 
                                                         'Yellowstone National Park': 'Yellowstone'})

# %%
obs_df[obs_df['scientific_name'] == 'Echinochloa crus-galli'].sort_values(by='park_name')
# Out:
#               scientific_name                            park_name  \
# 802    Echinochloa crus-galli                  Bryce National Park
# 11435  Echinochloa crus-galli                  Bryce National Park
# 1454   Echinochloa crus-galli  Great Smoky Mountains National Park
# 7263   Echinochloa crus-galli  Great Smoky Mountains National Park
# 11688  Echinochloa crus-galli            Yellowstone National Park
# 17581  Echinochloa crus-galli            Yellowstone National Park
# 443    Echinochloa crus-galli               Yosemite National Park
# 17639  Echinochloa crus-galli               Yosemite National Park
#
#        observations
# 802             112
# 11435           116
# 1454             62
# 7263             62
# 11688           254
# 17581           235
# 443             159
# 17639           172

# %%
spec_df[spec_df['scientific_name'] == 'Canis lupus']
# Out:
#      category scientific_name     common_names conservation_status
# 8      Mammal     Canis lupus        Gray Wolf          Endangered
# 3020   Mammal     Canis lupus  Gray Wolf, Wolf         In Recovery
# 4448   Mammal     Canis lupus  Gray Wolf, Wolf          Endangered

# %%
spec_df[spec_df['common_names'] == 'Dicranum Moss'].drop('conservation_status', axis = 1)
# Out:
#                category      scientific_name   common_names
# 2737  Nonvascular Plant  Dicranum flagellare  Dicranum Moss
# 2738  Nonvascular Plant      Dicranum fulvum  Dicranum Moss
# 2739  Nonvascular Plant  Dicranum fuscescens  Dicranum Moss
# 2741  Nonvascular Plant   Dicranum polysetum  Dicranum Moss
# 2742  Nonvascular Plant   Dicranum scoparium  Dicranum Moss
# 2743  Nonvascular Plant     Dicranum spurium  Dicranum Moss
# 2745  Nonvascular Plant      Dicranum viride  Dicranum Moss

# %%
park_species_count = bio_df.groupby(['park_name'])[['scientific_name']].count()
park_species_count
# Out:
#                                      scientific_name
# park_name
# Bryce National Park                             5541
# Great Smoky Mountains National Park             5541
# Yellowstone National Park                       5541
# Yosemite National Park                          5541

# %%
# count species by category

category_species_count = spec_df.groupby('category')[['scientific_name']].count()
category_species_count.rename({'scientific_name': 'scientific_name_count'}, inplace= True, axis= 1)

plt.subplots(figsize= (12, 6)) 
plt.ticklabel_format(style= 'plain', axis= 'y')
sns.barplot(data= category_species_count, x= category_species_count.index, y= 'scientific_name_count', 
            order= category_species_count.sort_values('scientific_name_count', ascending= False).index)
plt.title('Species Count per Category',fontsize=18)
plt.xlabel('')
plt.ylabel('Species Count', fontsize= 14)
plt.xticks(fontsize= 12);
plt.yticks(fontsize= 12);
plt.savefig('Species Count per Category.png', dpi= 600)

# %%
# sum observations by category

category_obs = bio_df.groupby('category')[['observations']].sum()

fig, ax = plt.subplots(figsize=(12, 6)) 
plt.ticklabel_format(style='plain', axis='y')
sns.barplot(data= category_obs, x=category_obs.index, y= 'observations', 
            order=category_obs.sort_values('observations', ascending= False).index)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'k'))
plt.title('All Parks\' Observations by Category',fontsize=18)
plt.xlabel('', fontsize=14)
plt.ylabel('Observations', fontsize=14)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);
plt.savefig('All Parks\' Observations by Category.png', dpi= 600)

# %%
# count species by status

status_species_count = spec_df.loc[spec_df['conservation_status'] != 'None']
status_species_count = status_species_count.groupby('conservation_status')[['scientific_name']].count()
status_species_count

fig, ax = plt.subplots(figsize= (12, 3)) 
plt.ticklabel_format(style= 'plain', axis= 'y')
sns.barplot(data= status_species_count, x= status_species_count.index, y= 'scientific_name', 
            order= status_species_count.sort_values('scientific_name', ascending= False).index)
plt.title('Species Count per Conservation Status',fontsize=18)
plt.xlabel('Conservation Status', fontsize= 14)
plt.ylabel('Species Count', fontsize= 14)
plt.xticks(fontsize= 12);
plt.yticks(fontsize= 12);
fig.tight_layout()
plt.savefig('Species Count per Conservation Status.png', dpi= 600)

# %%
# sum observations by status

status_obs = bio_df.loc[bio_df['conservation_status'] != 'None']
status_obs = status_obs.groupby('conservation_status')[['observations']].sum()
status_obs

fig, ax = plt.subplots(figsize=(12, 3)) 
plt.ticklabel_format(style='plain', axis='y')
sns.barplot(data= status_obs, x=status_obs.index, y= 'observations', 
            order=status_obs.sort_values('observations', ascending= False).index)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'k'))
plt.title('All Parks\' Observations by Conservation Status',fontsize=18)
plt.xlabel('Conservation Status', fontsize=14)
plt.ylabel('Observations', fontsize=14)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);
fig.tight_layout()
plt.savefig('All Parks\' Observations by Conservation Status.png', dpi= 600)

# %%
# sum observations by park

park_obs = bio_df.groupby('park_name')[['observations']].sum()
park_obs.index = ['Bryce', 'Great Smoky Mountains', 'Yellowstone', 'Yosemite']

fig, ax = plt.subplots(figsize=(12, 3)) 
plt.ticklabel_format(style='plain', axis='y')
sns.barplot(data= park_obs, x=park_obs.index, y= 'observations', 
            order= park_obs.sort_values('observations', ascending= False).index)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'k'))
plt.title('Total Observations by Park',fontsize=18)
plt.ylabel('Observations', fontsize=14)
plt.xticks(fontsize=12);
plt.yticks(fontsize=12);
plt.savefig('Total Observations by Park.png', dpi= 600)

# %%
# create a df of the park acreage

park_acres = {'acres': [35835, 522427, 2219791, 747956]}
park_labels = ['Bryce', 'Great Smoky Mountains', 'Yellowstone', 'Yosemite']
park_size = pd.DataFrame(park_acres, index= park_labels)
park_size.index.name = 'park_name'

fig, ax = plt.subplots(figsize= (12, 3)) 
plt.ticklabel_format(style= 'plain', axis= 'y')
sns.barplot(data= park_size, x= park_size.index, y= 'acres', 
            order= ['Yellowstone', 'Yosemite', 'Bryce', 'Great Smoky Mountains'])
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'k'))
plt.title('Parks by Size (Acres)',fontsize=18)
plt.ylabel('Acres', fontsize= 14)
plt.xlabel('')
plt.xticks(fontsize= 12);
plt.yticks(fontsize= 12);
plt.savefig('Parks by Size (Acres).png', dpi= 600)

# %%
# plot observations per acre across parks

obs_per_acre = pd.merge(park_obs, park_size, left_index=True, right_index=True)
obs_per_acre['observations_per_acre'] = obs_per_acre['observations'] / obs_per_acre['acres']
obs_per_acre.index = ['Bryce', 'Great Smoky Mountains', 'Yellowstone', 'Yosemite']

fig, ax = plt.subplots(figsize= (12, 3)) 
plt.ticklabel_format(style= 'plain', axis= 'y')
sns.barplot(data= obs_per_acre, x= obs_per_acre.index, y= 'observations_per_acre', 
            order= ['Yellowstone', 'Yosemite', 'Bryce', 'Great Smoky Mountains'])
plt.title('Observations per Acre by Park',fontsize=18)
plt.ylabel('Observations per Acre', fontsize= 14)
plt.xticks(fontsize= 12);
plt.yticks(fontsize= 12);
plt.savefig('Observations per Acre by Park.png', dpi= 600)

# %%
# Create a boxplot of observations on the x-axis, and categories on the y-axis

f, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x= 'observations', y= 'category', data=bio_df, width=.6, color='skyblue')
plt.title('Disribution of Species\' Observations by Category (All Parks)', fontsize=18, y=1.025)
plt.xlabel('Observations', fontsize=14)
f.tight_layout()
plt.ylabel('')
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.savefig('Distribution of Species\' Observations by Category (All Parks).png', dpi= 600)

# %%
# Create a histplots of species observations per category

categories = ['Mammal', 'Vascular Plant', 'Bird', 'Amphibian', 'Reptile', 'Nonvascular Plant', 'Fish']

fig = plt.figure(figsize=(10, 12))
plt.subplots_adjust(hspace= 0.40, wspace= 0.40)
plt.suptitle('Observation Distributions by Category (All Parks)', fontsize=18, y=1)
fig.text(0.5, 0.005, 'Observations', ha="center", va='center', fontsize=14)

# loop through the length of statuses and keep track of indices
for m, category in enumerate(categories, 1):
        
    ax = plt.subplot(7, 1, m)

    # add a new subplot iteratively
    plot_data = bio_df[bio_df.category == category]

    sns.histplot(x= 'observations', data=plot_data, color='skyblue')

    # formatting the figures & plots
    ax.set_title(category.title())
    ax.set_xlabel('')
    ax.set_ylabel('Count')

fig.tight_layout()
plt.savefig('Observation Distributions by Category (All Parks).png', dpi= 600)

# %%
# Create a histplots of species observations by category by park

bio_df_short = bio_df.replace({'Bryce National Park': 'Bryce',
                               'Great Smoky Mountains National Park': 'G.S.M.',
                               'Yosemite National Park': 'Yosemite',
                               'Yellowstone National Park': 'Yellowstone'})

categories = ['Mammal', 'Vascular Plant', 'Bird', 'Amphibian', 'Reptile', 'Nonvascular Plant', 'Fish']
parks = ['G.S.M.', 'Bryce', 'Yosemite', 'Yellowstone']

fig = plt.figure(figsize=(10, 12))
plt.subplots_adjust(hspace= 0.40, wspace= 0.40)
plt.suptitle('Observation Distributions by Category & Park', fontsize=18, y=1)
fig.text(0.5, 0.005, 'Observations', ha="center", va='center', fontsize=14)

i = 0
# loop through the length of statuses and keep track of indices
for m, category in enumerate(categories, 1):
    for n, park in enumerate(parks, 1):
           
        i = i + 1
        ax = plt.subplot(7, 4, i)
        
        # add a new subplot iteratively
        plot_data = bio_df_short[(bio_df_short.category == category) & (bio_df_short.park_name == park)]
        sns.histplot(x= 'observations', data=plot_data, color='skyblue', edgecolor='white')

        # formatting the figures & plots
        ax.set_title(park.title())
        ax.set_xlabel('')
        ax.set_ylabel(category.title())
                
fig.tight_layout()
plt.savefig('Observation Distributions by Category & Park.png', dpi= 600)

# %%
# Create a plot of species' observations by conservation status

fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x= 'observations', y= 'conservation_status', data=bio_df_troubled, width=.6, palette= 'Spectral_r');
plt.title('Distribution of Species\' Observations by Conservation Staus', fontsize=18, y=1.025);
plt.xlabel('Observations', fontsize=14)
plt.ylabel('')
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
fig.tight_layout()
plt.savefig('Distribution of Species\' Observations by Conservation Status.png', dpi= 600)

# %%
# plot boxplots of observations by status for each park

fig = plt.figure(figsize=(12, 7))
plt.subplots_adjust(hspace= 0.25, wspace= 0.30)
plt.title('Distribution of Status\' Observations by Park', fontsize=18, y=1.025)

# filter df and plot each status's observations by plot on the new subplot axes
ax = sns.boxplot(data= bio_df_troubled_renamed_parks, 
                 x= 'observations', 
                 y= 'park_name', 
                 hue= 'conservation_status', 
                 width= 0.8, 
                 palette= 'Spectral_r', 
                 order= ['Great Smoky Mountains', 'Bryce', 'Yosemite', 'Yellowstone'])

# formatting the figures & plots
ax.set_ylabel('')
ax.set_xlabel('')
plt.xlabel('Observations', fontsize=14)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.yticks(rotation = 35)
plt.legend(title= 'Conservation Status')

plt.savefig('Distribution of Status\' Observations by Park.png', dpi= 600, bbox_inches='tight')

# %%
# plot boxplots of normalized observations by status for each park

normed_df = bio_df_troubled_renamed_parks

parks = ['Great Smoky Mountains', 'Bryce', 'Yosemite', 'Yellowstone']

for park in parks:
    park_obs_min = normed_df['observations'][normed_df['park_name'] == park].min()
    park_obs_max = normed_df['observations'][normed_df['park_name'] == park].max()
    park_obs_rng = park_obs_max - park_obs_min
    for idx, row in normed_df.iterrows():
        if  normed_df.loc[idx,'park_name'] == park:
            normed_df.loc[idx, 'obs2'] = (normed_df.loc[idx,'observations'] - park_obs_min) / park_obs_rng
            
fig = plt.figure(figsize=(12, 7))
plt.subplots_adjust(hspace= 0.25, wspace= 0.30)
plt.title('Normalized Distribution of Status\' Observations by Park', fontsize=18, y=1.025)

# filter df and plot each status's observations by plot on the new subplot axes
ax = sns.boxplot(data= normed_df, 
                 x= 'obs2', 
                 y= 'park_name', 
                 hue= 'conservation_status', 
                 width= 0.8, 
                 palette= 'Spectral_r', 
                 order= ['Great Smoky Mountains', 'Bryce', 'Yosemite', 'Yellowstone'])

# formatting the figures & plots
ax.set_ylabel('')
ax.set_xlabel('')
plt.xlabel('Observations', fontsize=14)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.yticks(rotation = 35)
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left")

plt.savefig('Normalized Distribution of Status\' Observations by Park', dpi= 600, bbox_inches='tight')

# %%
# plot boxplots of observations by status for each park

parks= ['Great Smoky Mountains', 'Bryce', 'Yosemite', 'Yellowstone']
statuses = ['In Recovery', 'Species of Concern', 'Threatened', 'Endangered']

fig = plt.figure(figsize=(14, 10))
plt.subplots_adjust(hspace= 0.40, wspace= 0.40)
plt.suptitle('Normalized Observation Distributions by Park & Status', fontsize=18, y=0.95)
fig.text(0.5,0.08, 'Normalized Observations', ha="center", va='center', fontsize=14)

# loop through the length of statuses and keep track of indices
for n, park in enumerate(parks):
    for m, status in enumerate(statuses):
        ax = plt.subplot(4, 4, (n * 4) + m + 1)
        # add a new subplot iteratively
        

        # filter df and plot each status's observations by plot on the new subplot axes
        bio_df_park = normed_df.loc[(normed_df.park_name == park) & 
                                    (normed_df.conservation_status == status)]
        sns.histplot(data= bio_df_park, x= 'obs2')

        # formatting the figures & plots
        ax.set_title(status.title())
        ax.set_xlabel('')
        ax.set_ylabel(park.title())
                
plt.savefig('Normalized Observation Distributions by Park & Status.png', dpi= 600)

# %%
# plot boxplots of observations by status for each park

parks= ['Great Smoky Mountains', 'Bryce', 'Yosemite', 'Yellowstone']

fig = plt.figure(figsize=(14, 10))
plt.subplots_adjust(hspace= 0.25, wspace= 0.30)
plt.suptitle('Distribution of Status\' Observations by Park', fontsize=18, y=0.95)
fig.text(0.5,0.08, 'Observations', ha="center", va='center', fontsize=14)

# loop through the length of statuses and keep track of index
for n, park in enumerate(parks):
    # add a new subplot iteratively
    ax = plt.subplot(2, 2, n + 1)

    # filter df and plot each status's observations by plot on the new subplot axes
    bio_df_park = bio_df_troubled_renamed_parks.loc[(bio_df_troubled_renamed_parks.park_name == park)]
    sns.boxplot(data= bio_df_park, x= 'observations', y= 'conservation_status', width= 0.6, order= ['In Recovery',
                                                                                            'Species of Concern',
                                                                                            'Threatened',
                                                                                            'Endangered'], palette= 'Spectral_r')

    # formatting the figures & plots
    ax.set_title(park.title())
    ax.set_xlabel('')
    ax.set_ylabel('')
    plt.yticks(rotation = 45)

plt.savefig('Distribution of Status\' Observations by Park.png', dpi= 600)

# %%
# plot boxplots of observations by park for each status

bio_df_troubled_renamed_parks_short = bio_df_troubled.replace({'Bryce National Park': 'Bryce', 
                                                         'Great Smoky Mountains National Park': 'G.S.M.', 
                                                         'Yosemite National Park': 'Yosemite', 
                                                         'Yellowstone National Park': 'Yellowstone'})

# define unique statuses for loop
statuses = bio_df_troubled_renamed_parks_short['conservation_status'].unique()

fig = plt.figure(figsize=(14, 10))
plt.subplots_adjust(hspace= 0.25, wspace= 0.30)
plt.suptitle('Distribution of Parks\' Observations by Status', fontsize=18, y=0.95)
fig.text(0.5,0.08, 'Observations', ha= 'center', va= 'center', fontsize=14)

# loop through the length of statuses and keep track of index
for n, status in enumerate(statuses):
    # add a new subplot iteratively
    ax = plt.subplot(2, 2, n + 1)

    # filter df and plot each status's observations by plot on the new subplot axes
    bio_df_status = bio_df_troubled_renamed_parks_short.loc[(bio_df_troubled_renamed_parks.conservation_status == status)]
    sns.boxplot(data= bio_df_status, x= 'observations', y= 'park_name', width= 0.6, order= ['G.S.M.', 'Bryce', 'Yosemite', 'Yellowstone'])

    # formatting the figures & plots
    ax.set_title(status.title())
    ax.set_xlabel('')
    ax.set_ylabel('')
    plt.yticks(rotation = 45)

# plt.tight_layout()
plt.savefig('Distribution of Parks\' Observations by Status', dpi= 600)

# %%
print(bio_df_troubled_renamed_parks.loc[
    (bio_df_troubled_renamed_parks['category'] == 'Nonvascular Plant') & 
    (bio_df_troubled_renamed_parks['conservation_status'] == 'Threatened' )
])
# Out:
# Empty DataFrame
# Columns: [category, scientific_name, conservation_status, common_names, park_name, observations, obs2]
# Index: []

# %%
# plot boxplots of observations by status for each species category

fig = plt.figure(figsize=(12, 7))
plt.subplots_adjust(hspace= 0.25, wspace= 0.30)
plt.title('Distribution of Categories\' Observations by Status', fontsize=18, y=1.025)

# filter df and plot each status's observations by plot on the new subplot axes
ax = sns.boxplot(data= bio_df_troubled_renamed_parks, x= 'observations', y= 'category', hue= 'conservation_status', width= 0.8, palette= 'Spectral_r')

# formatting the figures & plots
ax.set_ylabel('')
ax.set_xlabel('')
plt.xlabel('Observations', fontsize=14)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.yticks(rotation = 35)
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left") 

plt.savefig('Distribution of Categories\' Observations by Status.png', dpi= 600, bbox_inches='tight')

# %%
# plot boxplots category  observations for each park

bio_df_short = bio_df.replace({'Bryce National Park': 'Bryce',
                               'Great Smoky Mountains National Park': 'G.S.M.',
                               'Yosemite National Park': 'Yosemite',
                               'Yellowstone National Park': 'Yellowstone'})

# define unique statuses for loop
categories = bio_df['category'].unique()

fig = plt.figure(figsize=(14, 10))
plt.subplots_adjust(hspace= 0.25, wspace= 0.30)
plt.suptitle('Distribution of Categories\' Observations by Park', fontsize=18, y=0.95)
fig.text(0.5,0.08, 'Observations', ha="center", va='center', fontsize=14)

# loop through the length of statuses and keep track of index
for n, category in enumerate(categories):
    # add a new subplot iteratively
    ax = plt.subplot(3, 3, n + 1)

    # filter df and plot each status's observations by plot on the new subplot axes
    bio_df_category = bio_df_short.loc[(bio_df.category == category)]
    sns.boxplot(data= bio_df_category, x= 'observations', y= 'park_name', width= 0.6, order= ['G.S.M.', 'Bryce', 'Yosemite', 'Yellowstone'])

    # formatting the figures & plots
    ax.set_title(category.title())
    ax.set_xlabel('')
    ax.set_ylabel('')
    plt.yticks(rotation = 45)

plt.savefig('Distribution of Categories\' Observations by Park.png', dpi= 600)

# %%
# plot stacked bar plot of species count by protected category

category_troubled_count = bio_df_troubled_renamed_parks.groupby(['category', 'conservation_status'])[['scientific_name']].nunique().unstack('conservation_status')
category_troubled_count = category_troubled_count.droplevel(0, axis=1)
category_troubled_count.columns.name = None
category_troubled_count.index.name = None
category_troubled_count = category_troubled_count.fillna(0)
category_troubled_count = category_troubled_count.reindex(['Fish', 'Amphibian', 'Mammal', 'Bird', 'Vascular Plant', 'Nonvascular Plant', 'Reptile'])

totals = [i+j+k+l for i,j,k,l in zip(category_troubled_count['Species of Concern'],
                                     category_troubled_count['In Recovery'], 
                                     category_troubled_count['Threatened'], 
                                     category_troubled_count['Endangered'])
         ]

SOCBars = [i / j * 100 for i,j in zip(category_troubled_count['Species of Concern'], totals)]
IRBars = [i / j * 100 for i,j in zip(category_troubled_count['In Recovery'], totals)]
TBars = [i / j * 100 for i,j in zip(category_troubled_count['Threatened'], totals)]
EBars = [i / j * 100 for i,j in zip(category_troubled_count['Endangered'], totals)]

# plot
barWidth = 0.6
names = category_troubled_count.columns.tolist()

fig, ax = plt.subplots(figsize=(12, 7))
plt.title('Troubled Status\' Percentage of Individual Species in Category', fontsize=18, y=1.025)
# Create in recovery Bars
plt.bar(category_troubled_count.index, IRBars, color= '#72B7A1', edgecolor='white', width=barWidth, label= 'In Recovery')
# Create species of concern Bars
plt.bar(category_troubled_count.index, SOCBars, bottom= IRBars, color= '#DEE9A4', edgecolor= 'white', width=barWidth, label= 'Species of Concern')
# Create threatened Bars
plt.bar(category_troubled_count.index, TBars, bottom= [i+j for i,j in zip(SOCBars, IRBars)], color= '#F0D999', edgecolor= 'white', width= barWidth, label= 'Threatened')
# Create endangered Bars
plt.bar(category_troubled_count.index, EBars, bottom=[i+j+k for i,j,k in zip(SOCBars, IRBars, TBars)], color= '#DE7959', edgecolor= 'white', width= barWidth, label= 'Endangered')

# Custom x axis
plt.xticks(category_troubled_count.index, fontsize= 12, rotation= 15)
plt.xlabel("Category", fontsize= 14)
plt.ylabel("Percentage", fontsize= 14)

# Add a legend
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left")

plt.savefig('Troubled Status\' Percentage of Individual Species in Category.png', dpi= 600, bbox_inches='tight')

# %%
# plot above with No Status

category_status_count = bio_df.groupby(['category', 'conservation_status'])[['scientific_name']].nunique().unstack('conservation_status')
category_status_count = category_status_count.droplevel(0, axis=1)
category_status_count.columns.name = None
category_status_count.index.name = None
category_status_count = category_status_count.fillna(0)
category_status_count = category_status_count.reindex(['Mammal', 'Bird', 'Fish', 'Amphibian', 'Reptile', 'Vascular Plant', 'Nonvascular Plant'])

totals = [i+j+k+l+m for i,j,k,l,m in zip(category_status_count['None'],
                                     category_status_count['Species of Concern'],
                                     category_status_count['In Recovery'], 
                                     category_status_count['Threatened'], 
                                     category_status_count['Endangered'])
         ]

NoneBars = [i / j * 100 for i,j in zip(category_status_count['None'], totals)] 
SOCBars = [i / j * 100 for i,j in zip(category_status_count['Species of Concern'], totals)]
IRBars = [i / j * 100 for i,j in zip(category_status_count['In Recovery'], totals)]
TBars = [i / j * 100 for i,j in zip(category_status_count['Threatened'], totals)]
EBars = [i / j * 100 for i,j in zip(category_status_count['Endangered'], totals)]

# plot
barWidth = 0.6
names = category_status_count.columns.tolist()

fig, ax = plt.subplots(figsize=(12, 7))
plt.title('Percentage of Individual Species in Status by Category', fontsize=18, y=1.025);
# Create none Bars
plt.bar(category_status_count.index, NoneBars, color= '#72B7A1', edgecolor= 'white', width=barWidth, label= 'None');
# Create in recovery Bars
plt.bar(category_status_count.index, IRBars, bottom= NoneBars, color= 'yellowgreen', edgecolor='white', width=barWidth, label= 'In Recovery');
# Create species of concern Bars
plt.bar(category_status_count.index, SOCBars, bottom= [i+j for i,j in zip(NoneBars, IRBars)], color= '#DEE9A4', edgecolor= 'white', width=barWidth, label= 'Species of Concern');
# Create threatened Bars
plt.bar(category_status_count.index, TBars, bottom= [i+j+k for i,j,k in zip(NoneBars, IRBars, SOCBars)], color= '#F0D999', edgecolor= 'white', width= barWidth, label= 'Threatened');
# Create endangered Bars
plt.bar(category_status_count.index, EBars, bottom=[i+j+k+l for i,j,k,l in zip(NoneBars, IRBars, SOCBars, TBars)], color= '#DE7959', edgecolor= 'white', width= barWidth, label= 'Endangered');

# Custom x axis
plt.xticks(category_status_count.index, fontsize= 12, rotation= 15);
plt.ylabel("Percentage", fontsize= 14);

# Add a legend
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left");

plt.savefig('Percentage of Individual Species in Status by Category.png', dpi= 600, bbox_inches='tight')

# %%
# plot above with No Status and without percentage

category_status_count = bio_df.groupby(['category', 'conservation_status'])[['scientific_name']].nunique().unstack('conservation_status')
category_status_count = category_status_count.droplevel(0, axis=1)
category_status_count.columns.name = None
category_status_count.index.name = None
category_status_count = category_status_count.fillna(0)
category_status_count = category_status_count.reindex(['Mammal', 'Bird', 'Fish', 'Amphibian', 'Reptile', 'Vascular Plant', 'Nonvascular Plant'])

NoneBars = category_status_count['None']
SOCBars = category_status_count['Species of Concern']
IRBars = category_status_count['In Recovery']
TBars = category_status_count['Threatened']
EBars = category_status_count['Endangered']

# plot
barWidth = 0.6
names = category_status_count.columns.tolist()

fig, ax = plt.subplots(figsize=(12, 7))
plt.title('Status of Individual Species in Category', fontsize=18, y=1.025);
# Create none Bars
plt.bar(category_status_count.index, NoneBars, color= '#72B7A1', edgecolor= 'white', width=barWidth, label= 'None');
# Create in recovery Bars
plt.bar(category_status_count.index, IRBars, bottom= NoneBars, color= 'yellowgreen', edgecolor='white', width=barWidth, label= 'In Recovery');
# Create species of concern Bars
plt.bar(category_status_count.index, SOCBars, bottom= [i+j for i,j in zip(NoneBars, IRBars)], color= '#DEE9A4', edgecolor= 'white', width=barWidth, label= 'Species of Concern');
# Create threatened Bars
plt.bar(category_status_count.index, TBars, bottom= [i+j+k for i,j,k in zip(NoneBars, IRBars, SOCBars)], color= '#F0D999', edgecolor= 'white', width= barWidth, label= 'Threatened');
# Create endangered Bars
plt.bar(category_status_count.index, EBars, bottom=[i+j+k+l for i,j,k,l in zip(NoneBars, IRBars, SOCBars, TBars)], color= '#DE7959', edgecolor= 'white', width= barWidth, label= 'Endangered');

# Custom x axis
plt.xticks(category_status_count.index, fontsize= 12, rotation= 15);
plt.xlabel("Category", fontsize= 14);
plt.ylabel("Species Count", fontsize= 14);

# Add a legend
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left");

plt.savefig('Status of Individual Species in Category.png', dpi= 600, bbox_inches='tight')

# %%
# Try one of these grouped by observation and call it quits.

category_status_sum = bio_df.groupby(['category', 'conservation_status'])[['observations']].sum().unstack('conservation_status')
category_status_sum = category_status_sum.droplevel(0, axis=1)
category_status_sum.columns.name = None
category_status_sum.index.name = None
category_status_sum = category_status_sum.fillna(0)
category_status_sum = category_status_sum.reindex(['Mammal', 'Bird', 'Fish', 'Amphibian', 'Reptile', 'Vascular Plant', 'Nonvascular Plant'])

totals = [i+j+k+l+m for i,j,k,l,m in zip(category_status_sum['None'],
                                     category_status_sum['Species of Concern'],
                                     category_status_sum['In Recovery'], 
                                     category_status_sum['Threatened'], 
                                     category_status_sum['Endangered'])
         ]

NoneBars = [i / j * 100 for i,j in zip(category_status_sum['None'], totals)] 
SOCBars = [i / j * 100 for i,j in zip(category_status_sum['Species of Concern'], totals)]
IRBars = [i / j * 100 for i,j in zip(category_status_sum['In Recovery'], totals)]
TBars = [i / j * 100 for i,j in zip(category_status_sum['Threatened'], totals)]
EBars = [i / j * 100 for i,j in zip(category_status_sum['Endangered'], totals)]

# plot
barWidth = 0.6
names = category_status_sum.columns.tolist()

fig, ax = plt.subplots(figsize=(12, 7))
plt.title('Percentage of Observations in Status by Category', fontsize=18, y=1.025);
# Create none Bars
plt.bar(category_status_sum.index, NoneBars, color= '#72B7A1', edgecolor= 'white', width=barWidth, label= 'None');
# Create in recovery Bars
plt.bar(category_status_sum.index, IRBars, bottom= NoneBars, color= 'yellowgreen', edgecolor='white', width=barWidth, label= 'In Recovery');
# Create species of concern Bars
plt.bar(category_status_sum.index, SOCBars, bottom= [i+j for i,j in zip(NoneBars, IRBars)], color= '#DEE9A4', edgecolor= 'white', width=barWidth, label= 'Species of Concern');
# Create threatened Bars
plt.bar(category_status_sum.index, TBars, bottom= [i+j+k for i,j,k in zip(NoneBars, IRBars, SOCBars)], color= '#F0D999', edgecolor= 'white', width= barWidth, label= 'Threatened');
# Create endangered Bars
plt.bar(category_status_sum.index, EBars, bottom=[i+j+k+l for i,j,k,l in zip(NoneBars, IRBars, SOCBars, TBars)], color= '#DE7959', edgecolor= 'white', width= barWidth, label= 'Endangered');

# Custom x axis
plt.xticks(category_status_sum.index, fontsize= 12, rotation= 15);
plt.ylabel("Percentage", fontsize= 14);

# Add a legend
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left");

plt.savefig('Percentage of Observations in Status by Category.png', dpi= 600, bbox_inches='tight')

# %%
# plot stacked bar plot of observations by protected category

category_troubled_sum = bio_df_troubled_renamed_parks.groupby(['category', 'conservation_status'])[['observations']].sum().unstack('conservation_status')
category_troubled_sum = category_troubled_sum.droplevel(0, axis=1)
category_troubled_sum.columns.name = None
category_troubled_sum.index.name = None
category_troubled_sum = category_troubled_sum.fillna(0)
category_troubled_sum = category_troubled_sum.reindex(['Fish', 'Amphibian', 'Mammal', 'Bird', 'Vascular Plant', 'Nonvascular Plant', 'Reptile'])

totals = [i+j+k+l for i,j,k,l in zip(category_troubled_sum['Species of Concern'],
                                     category_troubled_sum['In Recovery'], 
                                     category_troubled_sum['Threatened'], 
                                     category_troubled_sum['Endangered'])
         ]

SOCBars = [i / j * 100 for i,j in zip(category_troubled_sum['Species of Concern'], totals)]
IRBars = [i / j * 100 for i,j in zip(category_troubled_sum['In Recovery'], totals)]
TBars = [i / j * 100 for i,j in zip(category_troubled_sum['Threatened'], totals)]
EBars = [i / j * 100 for i,j in zip(category_troubled_sum['Endangered'], totals)]

# plot
barWidth = 0.6
names = category_troubled_sum.columns.tolist()

fig, ax = plt.subplots(figsize=(12, 7))
plt.title('Troubled Status\' Percentage of Observations in Category', fontsize=18, y=1.025)
# Create in recovery Bars
plt.bar(category_troubled_sum.index, IRBars, color= 'yellowgreen', edgecolor='white', width=barWidth, label= 'In Recovery')
# Create species of concern Bars
plt.bar(category_troubled_sum.index, SOCBars, bottom= IRBars, color= '#DEE9A4', edgecolor= 'white', width=barWidth, label= 'Species of Concern')
# Create threatened Bars
plt.bar(category_troubled_sum.index, TBars, bottom= [i+j for i,j in zip(SOCBars, IRBars)], color= '#F0D999', edgecolor= 'white', width= barWidth, label= 'Threatened')
# Create endangered Bars
plt.bar(category_troubled_sum.index, EBars, bottom=[i+j+k for i,j,k in zip(SOCBars, IRBars, TBars)], color= '#DE7959', edgecolor= 'white', width= barWidth, label= 'Endangered')

# Custom x axis
plt.xticks(category_troubled_sum.index, fontsize= 12, rotation= 15)
plt.xlabel("Category", fontsize= 14)
plt.ylabel("Percentage", fontsize= 14)

# Add a legend
plt.legend(title= 'Conservation Status', bbox_to_anchor=(1.03,1), loc="upper left")

plt.savefig('Troubled Status\' Percentage of Observations in Category.png', dpi= 600, bbox_inches='tight')
